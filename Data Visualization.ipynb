# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# Load the CSV file
df = pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\india_job_market_dataset.csv")
df
# Out:
#          Job ID             Job Title Company Name Job Location    Job Type  \
# 0          JOB1     Software Engineer       Amazon    Ahmedabad   Full-time
# 1          JOB2   Marketing Executive      Infosys    Ahmedabad  Internship
# 2          JOB3     Financial Analyst     Deloitte       Jaipur    Contract
# 3          JOB4      Business Analyst       Amazon        Delhi   Full-time
# 4          JOB5     Software Engineer      Infosys        Delhi   Full-time
# ...         ...                   ...          ...          ...         ...
# 19995  JOB19996   Marketing Executive     Deloitte         Pune   Full-time
# 19996  JOB19997      Business Analyst    Accenture    Bangalore  Internship
# 19997  JOB19998      Graphic Designer        Wipro       Jaipur   Part-time
# 19998  JOB19999  Sales Representative      Infosys      Kolkata  Internship
# 19999  JOB20000      Business Analyst    Accenture       Mumbai   Part-time
#
# ...

# %%
sns.countplot(x="Job Title",data=df,hue="Job Title",palette='viridis')
plt.xticks(rotation=90)
plt.xlabel("Job Title",fontsize=12)
plt.ylabel("count",fontsize=14)
plt.title("count of roles by job titles",fontsize=13,color="green")
plt.show()

# %%
gb=df.groupby("Job Type").agg(job_count=("Job ID", "count"))
gb
# Out:
#             job_count
# Job Type
# Contract         4823
# Full-time        4981
# Internship       5085
# Part-time        5111

# %%
# Group by "job type" and count the number of "job ID"
gb = df.groupby("Job Type").agg({"Job ID":"count"})

# Plot a pie chart
plt.pie(gb['Job ID'],labels=gb.index,autopct="%1.2f%%")
plt.title('Distribution of Jobs by Type')
plt.show()

# %%
# Countplot with Job Title on x-axis and Salary Range as hue
sns.countplot(x="Job Title", data=df, hue="Salary Range", palette="spring")
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
# Countplot with Job Title on x-axis and Salary Range as hue
sns.countplot(x="Job Title", data=df, hue="Salary Range", palette="GnBu")
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1,1))
plt.show()
